# %%
import pandas as pd
import numpy as np
from sklearn import metrics, model_selection, ensemble, neighbors, svm, tree, neural_network, base
import matplotlib.pyplot as plt

import importlib
import datetime
import mlTest
import preprocessing
importlib.reload(mlTest)
importlib.reload(preprocessing)
# Out:
# <module 'preprocessing' from 'C:\\Users\\Chunlok Lo\\Documents\\cs4641\\supervised_learning\\implementation\\preprocessing.py'>

# %%
df = pd.read_csv("data/magic04.data", header=None)

# %%
df = preprocessing.convert_numeric(df, [10])

# %%
X, y = preprocessing.XySplit(df, 10)
X_train, X_val, X_test, X_train_val, y_train, y_val, y_test, y_train_val = mlTest.train_val_test_split(X, y, train_size=0.8, val_size=0.1)
# Out:
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
y.describe()
# Out:
# count    19020.000000
# mean         0.351630
# std          0.477492
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: 10, dtype: float64

# %%
X_val.shape
# Out:
# (1902, 10)

# %% [markdown]
# Initial Performance Testing:

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(X_train_val, y_train_val)
cnf_matrix, accuracy = mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
print(accuracy)
# Out:
# [[1101  163]
#  [ 154  484]]
# 0.8333333333333334

# %%
clf = ensemble.AdaBoostClassifier(random_state=0, n_estimators=200)
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# [[1157  107]
#  [ 184  454]]
# (array([[1157,  107],
#         [ 184,  454]], dtype=int64), 0.8470031545741324)

# %%
clf = svm.LinearSVC(random_state=0)
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# [[1226   38]
#  [ 435  203]]
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# (array([[1226,   38],
#         [ 435,  203]], dtype=int64), 0.7513144058885384)

# %%
clf = svm.SVC(random_state=0)
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [[1263    1]
#  [ 619   19]]
# (array([[1263,    1],
#         [ 619,   19]], dtype=int64), 0.6740273396424816)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import LeakyReLU, Activation
import numpy as np

model = Sequential()
model.add(Dense(10,input_shape=(10,)))
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('relu'))
model.add(Dense(1))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
hist = model.fit(X_train.values, y_train.values, epochs=200, validation_data=(X_val.values, y_val.values))
# Out:
# Train on 15216 samples, validate on 1902 samples
# Epoch 1/200
# 15216/15216 [==============================] - 3s 218us/step - loss: 5.7148 - acc: 0.0387 - val_loss: 5.5507 - val_acc: 0.0358
# Epoch 2/200
# 15216/15216 [==============================] - 3s 165us/step - loss: 5.7148 - acc: 0.0387 - val_loss: 5.5507 - val_acc: 0.0358
# Epoch 3/200
#  6176/15216 [===========>..................] - ETA: 1s - loss: 5.7468 - acc: 0.0368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-c9f7a2dae9a6> in <module>
#      13 model.add(Dense(1))
#      14 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ---> 15 hist = model.fit(X_train.values, y_train.values, epochs=200, validation_data=(X_val.values, y_val.values))
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     891                               class_weight=class_weight,
#     892                               sample_weight=sample_weight,
# --> 893                               initial_epoch=initial_epoch)
#     894
#     895     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1629                               initial_epoch=initial_epoch,
#    1630                               steps_per_epoch=steps_per_epoch,
# -> 1631                               validation_steps=validation_steps)
#    1632
#    1633     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
clf = neural_network.MLPClassifier(hidden_layer_sizes=(5, 2), random_state=0)
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# [[1118   92]
#  [ 256  436]]
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# (array([[1118,   92],
#         [ 256,  436]], dtype=int64), 0.8170347003154574)

# %% [markdown]
# Algorithm Testing:

# %% [markdown]
# Decision Tree Classifier:
# Testing: Pruning parameter min_impurity_decrease
# Testing: Max Depth

# %%
param = ('min_impurity_decrease', np.linspace(0, .002, num=10))
classifier = tree.DecisionTreeClassifier(random_state=0)
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
# mlTest.saveNpArray(train_acc, "MAGIC-decisionTree", descriptors="impurity-train_acc")
# mlTest.saveNpArray(test_acc, "MAGIC-decisionTree", descriptors="impurity-test_acc")
# mlTest.saveNpArray(param_vals, "MAGIC-decisionTree", descriptors="impurity-vals")
# Out:
# Processing Param Val: 0.00022222222222222223
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3c38550676d0> in <module>
#       2 plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#       3 classifier = tree.DecisionTreeClassifier(random_state=0)
# ----> 4 train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
#       5 print(np.max(test_acc))
#       6 print(param_vals[np.argmax(test_acc)])
#
# ~\Documents\cs4641\supervised_learning\implementation\mlTest.py in paramTest(classifier, parameter, X_train, y_train, X_val, y_val, cross_val, folds, scoring)
#     118
#     119         if cross_val:
# --> 120             cv_result = model_selection.cross_validate(clf, X_train, y_train, cv=folds, return_train_score=True, scoring=scoring)
#     121             train_acc.append(np.mean(cv_result['train_score']))
#     122             test_acc.append(np.mean(cv_result['test_score']))
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238             return_times=True, return_estimator=return_estimator,
#     239             error_score=error_score)
# --> 240         for train, test in cv.split(X, y, groups))
#     241
#     242     zipped_scores = list(zip(*scores))
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     364                                            min_impurity_split)
#     365
# --> 366         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     367
#     368         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
param = ('max_depth', np.linspace(1, 20, num=10))
classifier = tree.DecisionTreeClassifier(random_state=0)
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
# mlTest.saveNpArray(train_acc, "MAGIC-decisionTree", descriptors="max_depth-train_acc")
# mlTest.saveNpArray(test_acc, "MAGIC-decisionTree", descriptors="max_depth-test_acc")
# mlTest.saveNpArray(param_vals, "MAGIC-decisionTree", descriptors="max_depth-vals")
# Out:
# Processing Param Val: 20.088888888888899
# 0.8437911029239062
# 9.444444444444445

# %% [markdown]
# Min impurity decrease with max depth did not improve performance. So I just left it out.

# %%
param = ('min_impurity_decrease', np.linspace(0, .002, num=10))
classifier = tree.DecisionTreeClassifier(random_state=0, criterion='entropy')
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
# mlTest.saveNpArray(train_acc, "MAGIC-decisionTree", descriptors="impurity-train_acc")
# mlTest.saveNpArray(test_acc, "MAGIC-decisionTree", descriptors="impurity-test_acc")
# mlTest.saveNpArray(param_vals, "MAGIC-decisionTree", descriptors="impurity-vals")
# Out:
# Processing Param Val: 0.00277777777777777797
# 0.8505084267821736
# 0.0006666666666666668

# %%
#clf = tree.DecisionTreeClassifier(random_state=0, min_impurity_decrease=0.00022222222222222223)
#train_acc, test_acc, train_samples = mlTest.accuracy_vs_num_train_samples(clf, X_train_val, y_train_val, min_train_num=20)
mlTest.plot_accuracy(train_acc, test_acc, train_samples)

# %% [markdown]
# mlTest.saveNpArray(train_acc, "MAGIC-decisionTree", descriptors="tuned-train_acc")
# mlTest.saveNpArray(test_acc, "MAGIC-decisionTree", descriptors="tuned-test_acc")
# mlTest.saveNpArray(train_samples, "MAGIC-decisionTree", descriptors="tuned-vals")

# %%
clf = tree.DecisionTreeClassifier(min_impurity_decrease=0.00022222222222222223)
clf.fit(X_train_val, y_train_val)
cnf_matrix, accuracy = mlTest.show_confusion_matrix(clf, X_test, y_test, classes=['gamma', 'hadron'])
print(accuracy)
mlTest.saveNpArray(cnf_matrix, "MAGIC-decisionTree", descriptors="cnf_matrix")
# Out:
# [[1140   96]
#  [ 210  456]]
# 0.8391167192429022

# %%
y_ = clf.predict(X_test)
metrics.precision_recall_fscore_support(y_test,y_)
# Out:
# (array([0.84444444, 0.82608696]),
#  array([0.9223301 , 0.68468468]),
#  array([0.88167053, 0.74876847]),
#  array([1236,  666], dtype=int64))

# %% [markdown]
# ADA BOOST TESTING
#
#
# Testing: n_estimators
# learning rate?

# %%
param = ('n_estimators', np.linspace(1, 80, num=10, dtype=int))
classifier = ensemble.AdaBoostClassifier(random_state=0)
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
mlTest.saveNpArray(train_acc, "MAGIC-ADABoost", descriptors="n_estimators-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-ADABoost", descriptors="n_estimators-test_acc")
mlTest.saveNpArray(param_vals, "MAGIC-ADABoost", descriptors="n_estimators-vals")
# Out:
# Processing Param Val: 80
# 0.8447843908837515
# 80

# %%
param = ('n_estimators', np.linspace(1, 80, num=10, dtype=int))
classifier = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=2), random_state=0)
train_acc1, test_acc1, param_vals1 = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(test_acc, test_acc1, param_vals1)
mlTest.saveNpArray(train_acc1, "MAGIC-decisionTree", descriptors="n_estimators-train_acc-depth2")
mlTest.saveNpArray(test_acc1, "MAGIC-decisionTree", descriptors="n_estimators-test_acc-depth2")
mlTest.saveNpArray(param_vals1, "MAGIC-decisionTree", descriptors="n_estimators-vals-depth2")
# Out:
# Processing Param Val: 80
# 0.8492232776372785
# 150

# %%
#param = ('n_estimators', np.linspace(1, 80, num=10, dtype=int))
#classifier = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=3), random_state=0)
#train_acc3, test_acc3, param_vals3 = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc3))
print(param_vals3[np.argmax(test_acc3)])
mlTest.plot_accuracy(train_acc3, test_acc3, param_vals3)
mlTest.saveNpArray(train_acc3, "MAGIC-adaboost", descriptors="learning_rate-train_acc-depth3")
mlTest.saveNpArray(test_acc3, "MAGIC-adaboost", descriptors="learning_rate-test_acc-depth3")
mlTest.saveNpArray(param_vals3, "MAGIC-adaboost", descriptors="learning_rate-vals-depth3")
# Out:
# 0.8685598819076127
# 53

# %%
#\param = ('n_estimators', np.linspace(1, 80, num=10, dtype=int))
#classifier = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=4), random_state=0)
#train_acc4, test_acc4, param_vals4 = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc4))
print(param_vals3[np.argmax(test_acc4)])
mlTest.plot_accuracy(train_acc4, test_acc4, param_vals4)
mlTest.saveNpArray(train_acc4, "MAGIC-adaboost", descriptors="learning_rate-train_acc-depth4")
mlTest.saveNpArray(test_acc4, "MAGIC-adaboost", descriptors="learning_rate-test_acc-depth4")
mlTest.saveNpArray(param_vals4, "MAGIC-adaboost", descriptors="learning_rate-vals-depth4")
# Out:
# 0.8623097794916893
# 18

# %%
mlTest.plot_accuracy(test_acc1, test_acc3, param_vals3)

# %%
param = ('learning_rate', np.linspace(1, 0, num=10))
classifier = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=2), random_state=0)
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(test_acc, test_acc1, param_vals1)
# mlTest.saveNpArray(train_acc1, "MAGIC-adaboost", descriptors="learning_rate-train_acc-depth2")
# mlTest.saveNpArray(test_acc1, "MAGIC-adaboost", descriptors="learning_rate-test_acc-depth2")
# mlTest.saveNpArray(param_vals1, "MAGIC-adaboost", descriptors="learning_rate-vals-depth2")
# Out:
# Processing Param Val: 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-22c0deadb112> in <module>
#       1 param = ('learning_rate', np.linspace(1, 0, num=10))
#       2 classifier = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=2), random_state=0)
# ----> 3 train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
#       4 print(np.max(test_acc))
#       5 print(param_vals[np.argmax(test_acc)])
#
# ~\Documents\cs4641\supervised_learning\implementation\mlTest.py in paramTest(classifier, parameter, X_train, y_train, X_val, y_val, cross_val, folds, scoring)
#     114
#     115         if cross_val:
# --> 116             cv_result = model_selection.cross_validate(clf, X_train, y_train, cv=folds, return_train_score=True, scoring=scoring)
#     117             train_acc.append(np.mean(cv_result['train_score']))
#     118             test_acc.append(np.mean(cv_result['test_score']))
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238             return_times=True, return_estimator=return_estimator,
#     239             error_score=error_score)
# --> 240         for train, test in cv.split(X, y, groups))
#     241
#     242     zipped_scores = list(zip(*scores))
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\ensemble\weight_boosting.py in fit(self, X, y, sample_weight)
#     410
#     411         # Fit
# --> 412         return super(AdaBoostClassifier, self).fit(X, y, sample_weight)
#     413
#     414     def _validate_estimator(self):
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\ensemble\weight_boosting.py in fit(self, X, y, sample_weight)
#     141                 X, y,
#     142                 sample_weight,
# --> 143                 random_state)
#     144
#     145             # Early termination
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\ensemble\weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     470         """
#     471         if self.algorithm == 'SAMME.R':
# --> 472             return self._boost_real(iboost, X, y, sample_weight, random_state)
#     473
#     474         else:  # elif self.algorithm == "SAMME":
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\ensemble\weight_boosting.py in _boost_real(self, iboost, X, y, sample_weight, random_state)
#     480         estimator = self._make_estimator(random_state=random_state)
#     481
# --> 482         estimator.fit(X, y, sample_weight=sample_weight)
#     483
#     484         y_predict_proba = estimator.predict_proba(X)
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     364                                            min_impurity_split)
#     365
# --> 366         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     367
#     368         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
acc1 = np.load("npData/20190206-132640-MAGIC-ADABoost-n_estimators-test_acc.npy")
acc2 = np.load("npData/20190206-021010_MAGIC-adaboost_n_estimators-test_acc-depth2.npy")
acc3 = np.load("npData/20190206-120107-MAGIC-adaboost-learning_rate-test_acc-depth3.npy")
acc4 = np.load("npData/20190206-120139-MAGIC-adaboost-learning_rate-test_acc-depth4.npy")

# %%
vals2 = np.load("npData/20190206-021010_MAGIC-adaboost_n_estimators-vals-depth2.npy")

# %%
vals[np.argmax(acc)]
# Out:
# 62

# %%
fig = plt.figure()
fig.set_size_inches(8, 5)
plt.plot(param_vals, acc1, label='max_depth = 1', marker='.')
plt.plot(param_vals, acc2, label='max_depth = 2', marker='.')
plt.plot(param_vals, acc3, label='max_depth = 3', marker='.')
plt.plot(param_vals, acc4, label='max_depth = 4', marker='.')
plt.legend()
plt.grid()
plt.xticks(param_vals)
plt.xlabel('Number of Estimators')
plt.ylabel('Validation Accuracy')
plt.suptitle("AdaBoost")
plt.show()

# %%
clf = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=3), random_state=0, n_estimators=53)
clf.fit(X_train_val, y_train_val)
#cnf_matrx, accuracy = mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=53, random_state=0)

# %%
mlTest.saveNpArray(cnf_matrx, "MAGIC-ADABoost", descriptors="cnf_matrix")

# %%
y_ = clf.predict(X_test)
m = metrics.precision_recall_fscore_support(y_test,y_)
m = np.concatenate(([['Gamma', 'Hadron']], m), axis=0)
m = np.array(m).transpose()
from tabulate import tabulate
headers=['Class', 'Precision', 'Recall', 'F1 Score', 'Support']
print(tabulate(m, tablefmt="latex", floatfmt=".3f", headers=headers))
# Out:
# \begin{tabular}{lrrrr}
# \hline
#  Class   &   Precision &   Recall &   F1 Score &   Support \\
# \hline
#  Gamma   &       0.882 &    0.921 &      0.901 &  1230.000 \\
#  Hadron  &       0.843 &    0.774 &      0.807 &   672.000 \\
# \hline
# \end{tabular}

# %%
accuracy
# Out:
# 0.8706624605678234

# %%
y_ = clf.predict_proba(X_test)
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_NN)
mlTest.saveNpArray(fpr, "MAGIC-ADA", descriptors="fpr")
mlTest.saveNpArray(tpr, "MAGIC-ADA", descriptors="tpr")
plt.plot(fpr, tpr)

# %%
#clf = ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier(random_state=0, max_depth=3), random_state=0, n_estimators=53)
#train_acc, test_acc, train_samples = mlTest.accuracy_vs_num_train_samples(clf, X_train_val, y_train_val, min_train_num=100)
mlTest.plot_accuracy(train_acc, test_acc, train_samples)
mlTest.saveNpArray(train_acc, "MAGIC-adaboost", descriptors="sample-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-adaboost", descriptors="sample-test_acc")
mlTest.saveNpArray(train_samples, "MAGIC-adaboost", descriptors="sample-vals")

# %% [markdown]
# SVM TESTING

# %%
param = ('C', np.linspace(.001, 2, num=20))
classifier = svm.LinearSVC(random_state=0, max_iter=4000)
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy', folds=2)
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
mlTest.saveNpArray(train_acc, "MAGIC-LinearSVM", descriptors="C-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-LinearSVM", descriptors="C-test_acc")
mlTest.saveNpArray(param_vals, "MAGIC-LinearSVM", descriptors="C-vals")
# Out:
# Processing Param Val: 0.001
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.10621052631578948
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.21142105263157895
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.31663157894736843
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.4218421052631579
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.5270526315789473
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.6322631578947369
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.7374736842105264
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.8426842105263158
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 0.9478947368421052
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.0531052631578945
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.1583157894736842
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.2635263157894736
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.368736842105263
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.4739473684210527
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.579157894736842
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.6843684210526315
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.789578947368421
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 1.8947894736842104
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Processing Param Val: 2.0
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.7813996962261947
# 0.001
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
param = ('C', np.linspace(.001, 2, num=20))
classifier = svm.SVC(random_state=0, max_iter=4000, gamma='scale')
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy', folds=2)
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
mlTest.saveNpArray(train_acc, "MAGIC-SVM", descriptors="C-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-SVM", descriptors="C-test_acc")
mlTest.saveNpArray(param_vals, "MAGIC-SVM", descriptors="C-vals")
# Out:
# Processing Param Val: 0.10621052631578948
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.21142105263157895
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.31663157894736843
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.4218421052631579
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.5270526315789473
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.6322631578947369
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.7374736842105264
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.8426842105263158
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 0.9478947368421052
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.0531052631578945
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.1583157894736842
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.2635263157894736
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.368736842105263
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.4739473684210527
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.579157894736842
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.6843684210526315
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.789578947368421
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 1.8947894736842104
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Processing Param Val: 2.0
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 0.8240448650543288
# 1.6843684210526315

# %%
mlTest.plot_accuracy(train_acc, test_acc, param_vals)

# %%
clf = svm.SVC(C=1.6843684210526315, random_state=0, max_iter=4000, gamma='scale')
train_acc, test_acc, train_samples = mlTest.accuracy_vs_num_train_samples(clf, X_train_val, y_train_val, min_train_num=100)
mlTest.saveNpArray(train_acc, "MAGIC-SVM", descriptors="sample-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-SVM", descriptors="sample-test_acc")
mlTest.saveNpArray(train_samples, "MAGIC-SVM", descriptors="sample-vals")
# Out:
# 100
# iteration 3: training size: 3881
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 4: training size: 5772
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 5: training size: 7663
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 6: training size: 9554
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 7: training size: 11445
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 8: training size: 13336
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 9: training size: 15227
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# iteration 10: training size: 17118
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %%
mlTest.plot_accuracy(train_acc, test_acc, train_samples)

# %%
X_train_val.shape
# Out:
# (17118, 10)

# %%
clf = svm.SVC(C=1.6843684210526315, random_state=0, max_iter=4000, gamma='scale')
clf.fit(X_train_val, y_train_val)
y_ = clf.predict(X_test)
m = metrics.precision_recall_fscore_support(y_test,y_)
# Out:
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %%
m = np.concatenate(([['Gamma', 'Hadron']], m), axis=0)
m = np.array(m).transpose()
from tabulate import tabulate
headers=['Class', 'Precision', 'Recall', 'F1 Score', 'Support']
print(tabulate(m, tablefmt="latex", floatfmt=".3f", headers=headers))
# Out:
# \begin{tabular}{lrrrr}
# \hline
#  Class   &   Precision &   Recall &   F1 Score &   Support \\
# \hline
#  Gamma   &       0.840 &    0.934 &      0.885 &  1263.000 \\
#  Hadron  &       0.833 &    0.649 &      0.730 &   639.000 \\
# \hline
# \end{tabular}

# %%
clf = svm.SVC(C=1.6843684210526315, random_state=0, max_iter=4000, gamma='scale')
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\svm\base.py:244: ConvergenceWarning: Solver terminated early (max_iter=4000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [[1156   90]
#  [ 228  428]]
# (array([[1156,   90],
#         [ 228,  428]], dtype=int64), 0.832807570977918)

# %% [markdown]
# KNN Testing

# %%
#param = ('n_neighbors', np.linspace(1, 20, num=10, dtype=int))
#classifier = neighbors.KNeighborsClassifier()
#train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
#print(np.max(test_acc))
#print(param_vals[np.argmax(test_acc)])
#mlTest.plot_accuracy(train_acc, test_acc, param_vals)
mlTest.saveNpArray(train_acc, "MAGIC-knn", descriptors="n_neighbors-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-knn", descriptors="n_neighbors-test_acc")
mlTest.saveNpArray(param_vals, "MAGIC-knn", descriptors="n_neighbors-vals")

# %%
param = ('n_neighbors', np.linspace(1, 100, num=20, dtype=int))
classifier = neighbors.KNeighborsClassifier()
train_acc, test_acc, param_vals = mlTest.paramTest(classifier, param, X_train_val, y_train_val, scoring='accuracy')
print(np.max(test_acc))
print(param_vals[np.argmax(test_acc)])
mlTest.plot_accuracy(train_acc, test_acc, param_vals)
mlTest.saveNpArray(train_acc, "MAGIC-knn", descriptors="n_neighbors-train_acc-100")
mlTest.saveNpArray(test_acc, "MAGIC-knn", descriptors="n_neighbors-test_acc-100")
mlTest.saveNpArray(param_vals, "MAGIC-knn", descriptors="n_neighbors-vals-100")
# Out:
# Processing Param Val: 100
# 0.8115436273706071
# 11

# %% [markdown]
# Best value == 11. 0.8112 accuracy

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors=8)
train_acc, test_acc, train_samples = mlTest.accuracy_vs_num_train_samples(clf, X_train_val, y_train_val, min_train_num=50)
mlTest.plot_accuracy(train_acc, test_acc, train_samples)
# Out:
# 50
# iteration 10: training size: 17118

# %%
mlTest.saveNpArray(train_acc, "MAGIC-KNN", descriptors="tuned-train_acc")
mlTest.saveNpArray(test_acc, "MAGIC-KNN", descriptors="tuned-test_acc")
mlTest.saveNpArray(train_samples, "MAGIC-KNN", descriptors="tuned-vals")

# %%
np.max(test_acc)
# Out:
# 0.8088154145814015

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors=8)
clf.fit(X_train_val, y_train_val)
y_ = clf.predict(X_test)
m = metrics.precision_recall_fscore_support(y_test,y_)
m = np.concatenate(([['Gamma', 'Hadron']], m), axis=0)
m = np.array(m).transpose()
from tabulate import tabulate
headers=['Class', 'Precision', 'Recall', 'F1 Score', 'Support']
print(tabulate(m, tablefmt="latex", floatfmt=".3f", headers=headers))
# Out:
# \begin{tabular}{lrrrr}
# \hline
#  Class   &   Precision &   Recall &   F1 Score &   Support \\
# \hline
#  Gamma   &       0.804 &    0.946 &      0.869 &  1263.000 \\
#  Hadron  &       0.836 &    0.543 &      0.658 &   639.000 \\
# \hline
# \end{tabular}

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors=8)
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# [[1195   68]
#  [ 292  347]]
# (array([[1195,   68],
#         [ 292,  347]], dtype=int64), 0.8107255520504731)

# %% [markdown]
# Neural Network Tuning:
# Parameters: Network architecture.
# Batch sizes
# Need Training graph

# %%
clf = neural_network.MLPClassifier(hidden_layer_sizes=(5, 2), random_state=0)
clf.fit(X_train_val, y_train_val)
mlTest.show_confusion_matrix(clf, X_test, y_test, classes=[0, 1])
# Out:
# [[1130  113]
#  [ 216  443]]
# (array([[1130,  113],
#         [ 216,  443]], dtype=int64), 0.8270241850683491)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import LeakyReLU, Activation
import numpy as np
mc = keras.callbacks.ModelCheckpoint('weights{epoch:08d}.h5', 
                                     save_weights_only=True, period=5)
model = Sequential()
model.add(Dense(5,kernel_initializer='lecun_uniform',input_shape=(10,)))
model.add(Activation('relu'))
model.add(Dense(2, kernel_initializer='lecun_uniform'))
model.add(Activation('relu'))
model.add(Dense(1, kernel_initializer='lecun_uniform'))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#hist = model.fit(X_train.values, y_train.values, epochs=30, validation_data=(X_val.values, y_val.values), callbacks=[mc])

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import LeakyReLU, Activation
import numpy as np
mc = keras.callbacks.ModelCheckpoint('MAGIC-weights{epoch:08d}.h5', 
                                     save_weights_only=True, period=5)
model = Sequential()
model.add(Dense(20,kernel_initializer='lecun_uniform',input_shape=(10,)))
model.add(Activation('relu'))
model.add(Dense(8, kernel_initializer='lecun_uniform'))
model.add(Activation('relu'))
model.add(Dense(1, kernel_initializer='lecun_uniform'))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
hist2 = model.fit(X_train.values, y_train.values, epochs=30, validation_data=(X_val.values, y_val.values), callbacks=[mc])
# Out:
# Using TensorFlow backend.
# Train on 15216 samples, validate on 1902 samples
# Epoch 1/30
# 15216/15216 [==============================] - 3s 217us/step - loss: 1.4110 - acc: 0.6663 - val_loss: 0.6002 - val_acc: 0.7229
# Epoch 2/30
# 15216/15216 [==============================] - 2s 161us/step - loss: 0.5619 - acc: 0.7376 - val_loss: 0.5133 - val_acc: 0.7550
# Epoch 3/30
# 15216/15216 [==============================] - 2s 163us/step - loss: 0.5103 - acc: 0.7604 - val_loss: 0.4908 - val_acc: 0.7797
# Epoch 4/30
# 15216/15216 [==============================] - 2s 158us/step - loss: 0.4844 - acc: 0.7767 - val_loss: 0.4578 - val_acc: 0.8060
# Epoch 5/30
# 15216/15216 [==============================] - 2s 164us/step - loss: 0.4649 - acc: 0.7885 - val_loss: 0.4459 - val_acc: 0.8113
# Epoch 6/30
# 15216/15216 [==============================] - 2s 163us/step - loss: 0.4531 - acc: 0.7936 - val_loss: 0.4387 - val_acc: 0.8086
# Epoch 7/30
# 15216/15216 [==============================] - 2s 157us/step - loss: 0.4512 - acc: 0.7954 - val_loss: 0.4341 - val_acc: 0.8113
# Epoch 8/30
# 15216/15216 [==============================] - 2s 156us/step - loss: 0.4460 - acc: 0.8007 - val_loss: 0.4335 - val_acc: 0.8086
# Epoch 9/30
# 15216/15216 [==============================] - 2s 162us/step - loss: 0.4410 - acc: 0.8048 - val_loss: 0.4329 - val_acc: 0.8118
# Epoch 10/30
# 15216/15216 [==============================] - 2s 155us/step - loss: 0.4377 - acc: 0.8055 - val_loss: 0.4358 - val_acc: 0.8113
# Epoch 11/30
# 15216/15216 [==============================] - 3s 165us/step - loss: 0.4387 - acc: 0.8069 - val_loss: 0.4269 - val_acc: 0.8144
# Epoch 12/30
# 15216/15216 [==============================] - 2s 156us/step - loss: 0.4298 - acc: 0.8099 - val_loss: 0.4352 - val_acc: 0.8091
# Epoch 13/30
# 15216/15216 [==============================] - 2s 157us/step - loss: 0.4288 - acc: 0.8116 - val_loss: 0.4379 - val_acc: 0.8076
# Epoch 14/30
# 15216/15216 [==============================] - 3s 167us/step - loss: 0.4298 - acc: 0.8075 - val_loss: 0.4235 - val_acc: 0.8218
# Epoch 15/30
# 15216/15216 [==============================] - 3s 167us/step - loss: 0.4228 - acc: 0.8127 - val_loss: 0.4363 - val_acc: 0.8060
# Epoch 16/30
# 15216/15216 [==============================] - 3s 180us/step - loss: 0.4235 - acc: 0.8163 - val_loss: 0.4251 - val_acc: 0.8149
# Epoch 17/30
# 15216/15216 [==============================] - 3s 169us/step - loss: 0.4219 - acc: 0.8159 - val_loss: 0.4159 - val_acc: 0.8249
# Epoch 18/30
# 15216/15216 [==============================] - 3s 167us/step - loss: 0.4216 - acc: 0.8159 - val_loss: 0.4754 - val_acc: 0.8002
# Epoch 19/30
# 15216/15216 [==============================] - 2s 162us/step - loss: 0.4220 - acc: 0.8141 - val_loss: 0.4136 - val_acc: 0.8233
# Epoch 20/30
# 15216/15216 [==============================] - 2s 163us/step - loss: 0.4145 - acc: 0.8150 - val_loss: 0.4257 - val_acc: 0.8181
# Epoch 21/30
# 15216/15216 [==============================] - 3s 166us/step - loss: 0.4126 - acc: 0.8151 - val_loss: 0.4184 - val_acc: 0.8165
# Epoch 22/30
# 15216/15216 [==============================] - 2s 163us/step - loss: 0.4106 - acc: 0.8185 - val_loss: 0.4095 - val_acc: 0.8249
# Epoch 23/30
# 15216/15216 [==============================] - 3s 168us/step - loss: 0.4143 - acc: 0.8172 - val_loss: 0.4218 - val_acc: 0.8181
# Epoch 24/30
# 15216/15216 [==============================] - 3s 167us/step - loss: 0.4090 - acc: 0.8173 - val_loss: 0.4128 - val_acc: 0.8233
# Epoch 25/30
# 15216/15216 [==============================] - 3s 167us/step - loss: 0.4073 - acc: 0.8205 - val_loss: 0.4111 - val_acc: 0.8254
# Epoch 26/30
# 15216/15216 [==============================] - 3s 173us/step - loss: 0.4060 - acc: 0.8205 - val_loss: 0.4294 - val_acc: 0.8139
# Epoch 27/30
# 15216/15216 [==============================] - 3s 167us/step - loss: 0.4046 - acc: 0.8192 - val_loss: 0.4303 - val_acc: 0.8118
# Epoch 28/30
# 15216/15216 [==============================] - 2s 164us/step - loss: 0.4077 - acc: 0.8194 - val_loss: 0.4094 - val_acc: 0.8218
# Epoch 29/30
# 15216/15216 [==============================] - 3s 180us/step - loss: 0.4072 - acc: 0.8198 - val_loss: 0.4093 - val_acc: 0.8218
# Epoch 30/30
# 15216/15216 [==============================] - 3s 171us/step - loss: 0.4033 - acc: 0.8218 - val_loss: 0.4086 - val_acc: 0.8191

# %%
print(hist2.history.keys())
mlTest.saveObj(hist2.history, 'MAGIC-NN', descriptors='104-history')
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.plot(range(0, 30), hist2.history['val_acc'], label='validation accuracy')
plt.plot(range(0, 30), hist2.history['acc'], label='train accuracy')
plt.legend()
plt.show()

# %%
model.load_weights("MAGIC-weights00000030.h5")

# %%
plt.plot(range(3, 30), hist.history['val_loss'][3:], label='validation accuracy', marker='.')
plt.plot(range(3, 30), hist.history['loss'][3:], label='train accuracy', marker='.')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8b492f150d58> in <module>
# ----> 1 plt.plot(range(3, 30), hist.history['val_loss'][3:], label='validation accuracy', marker='.')
#       2 plt.plot(range(3, 30), hist.history['loss'][3:], label='train accuracy', marker='.')
#       3 plt.legend()
#       4 plt.show()
#
# NameError: name 'hist' is not defined

# %%
clf = model
classes=[0, 1]
y_ = clf.predict(X_test.values)
y_ = np.where(y_ > 0.5, 1, 0)
cnf_matrix = metrics.confusion_matrix(y_test.values, y_)
print(cnf_matrix)
plt.figure(figsize=(10, 10))
mlTest.plot_confusion_matrix(cnf_matrix, classes=classes, title='Confusion matrix')
accuracy = metrics.accuracy_score(y_test.values, y_)
print(accuracy)
# Out:
# [[1211   22]
#  [ 347  322]]
# 0.805993690851735

# %%
mlTest.show_confusion_matrix(model, X_test.values, y_test.values, classes=[0, 1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8746f9878148> in <module>
# ----> 1 mlTest.show_confusion_matrix(model, X_test.values, y_test.values, classes=[0, 1])
#
# ~\Documents\cs4641\supervised_learning\implementation\mlTest.py in show_confusion_matrix(clf, X_test, y_test, classes)
#      45 def show_confusion_matrix(clf, X_test, y_test, classes):
#      46     y_ = clf.predict(X_test)
# ---> 47     cnf_matrix = metrics.confusion_matrix(y_test, y_)
#      48     print(cnf_matrix)
#      49     plt.figure(figsize=(10, 10))
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
y_NN = model.predict(X_test.values)

# %%
y_NN
# Out:
# array([[0.82615936],
#        [0.3924553 ],
#        [0.39438105],
#        ...,
#        [0.22663334],
#        [0.9995493 ],
#        [0.22277461]], dtype=float32)

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_NN)
mlTest.saveNpArray(fpr, "MAGIC-NN", descriptors="fpr")
mlTest.saveNpArray(tpr, "MAGIC-NN", descriptors="tpr")
plt.plot(fpr, tpr)

# %%
plt.plot(fpr, tpr)

# %%
metrics.roc_auc_score(y_test, y_NN)
# Out:
# 0.8886989450251647

# %%
y_ = np.where(y_NN > 0.5, 1, 0)
print(y_)
# Out:
# [[1]
#  [0]
#  [0]
#  ...
#  [0]
#  [1]
#  [0]]

# %%
m = metrics.precision_recall_fscore_support(y_test,y_)
m = np.concatenate(([['Gamma', 'Hadron']], m), axis=0)
m = np.array(m).transpose()
from tabulate import tabulate
headers=['Class', 'Precision', 'Recall', 'F1 Score', 'Support']
print(tabulate(m, tablefmt="latex", floatfmt=".3f", headers=headers))
# Out:
# \begin{tabular}{lrrrr}
# \hline
#  Class   &   Precision &   Recall &   F1 Score &   Support \\
# \hline
#  Gamma   &       0.848 &    0.898 &      0.872 &  1230.000 \\
#  Hadron  &       0.791 &    0.705 &      0.746 &   672.000 \\
# \hline
# \end{tabular}

# %%
metrics.accuracy_score(y_test, y_)
# Out:
# 0.8301787592008412

# %%
cnf_matrix = metrics.confusion_matrix(y_test.values, y_)

# %%
cnf_matrix
# Out:
# array([[1105,  125],
#        [ 198,  474]], dtype=int64)
